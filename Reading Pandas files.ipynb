# %% [markdown]
# # Reading files

# %%
import pandas as pd

# %%
df = pd.read_csv(r"F:\Maya_Tech\Data_Analyst\Python\compnies.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
pd.set_option('display.max.rows', 101)

# %%
df = pd.read_csv(r"F:\Maya_Tech\Data_Analyst\Python\compnies.csv")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df.shape
# Out:
# (100, 7)

# %%
df.head(5)
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
df.tail(5)
# Out:
#     Rank                      Name                 Industry  \
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology
#
#    Revenue (USD millions) Revenue growth Employees             Headquarters
# 95                 46,298          10.6%    71,100     Richfield, Minnesota
# 96                 46,159           0.5%    34,300  New York City, New York
# 97                 44,955          82.5%    92,795        Chicago, Illinois
# 98                 44,915          14.5%   130,000   Waltham, Massachusetts
# 99                 44,200          31.7%    51,000    San Diego, California

# %%
df['Industry']
# Out:
# 0                                 Retail
# 1             Retail and cloud computing
# 2                     Petroleum industry
# 3                   Electronics industry
# 4                             Healthcare
# 5                             Healthcare
# 6                           Conglomerate
# 7         Technology and cloud computing
# 8                                 Health
# 9                     Petroleum industry
# 10                    Pharmacy wholesale
# 11                                Retail
# 12        Technology and cloud computing
# 13                            Healthcare
# 14                      Health insurance
# 15                    Petroleum industry
# 16                    Petroleum industry
# 17                    Petroleum industry
# 18                   Automotive industry
# 19                                Retail
# 20                   Automotive industry
# 21                            Healthcare
# 22                    Financial services
# ...

# %%
df.Industry.unique()
# Out:
# array(['Retail', 'Retail and cloud computing', 'Petroleum industry',
#        'Electronics industry', 'Healthcare', 'Conglomerate',
#        'Technology and cloud computing', 'Health', 'Pharmacy wholesale',
#        'Health insurance', 'Automotive industry', 'Financial services',
#        'Telecommunications', 'Pharmaceutical industry', 'Financials',
#        'Conglomerate and telecomunications', 'Technology',
#        'Food industry', 'Transportation', 'Beverage', 'Media',
#        'Automotive and energy', 'Consumer products manufacturing',
#        'Logistics', 'Food service', 'Aerospace and defense', 'Infotech',
#        'Machinery', 'Petroleum industry and logistics', 'Insurance',
#        'Chemical industry', 'Financial', 'Food processing',
#        'Agriculture manufacturing', 'Telecom hardware manufacturing',
#        'Airline', 'Agriculture cooperative', 'Apparel',
#        'Laboratory instruments'], dtype=object)

# %%
df.loc[23]
# Out:
# Rank                                    24
# Name                                Kroger
# Industry                            Retail
# Revenue (USD millions)             148,258
# Revenue growth                        7.5%
# Employees                          430,000
# Headquarters              Cincinnati, Ohio
# Name: 23, dtype: object

# %%
df.iloc[23]
# Out:
# Rank                                    24
# Name                                Kroger
# Industry                            Retail
# Revenue (USD millions)             148,258
# Revenue growth                        7.5%
# Employees                          430,000
# Headquarters              Cincinnati, Ohio
# Name: 23, dtype: object

# %% [markdown]
# # Filtering and ordering

# %%
df[df['Rank'] <= 15]
# Out:
#     Rank                  Name                        Industry  \
# 0      1               Walmart                          Retail
# 1      2                Amazon      Retail and cloud computing
# 2      3            ExxonMobil              Petroleum industry
# 3      4                 Apple            Electronics industry
# 4      5    UnitedHealth Group                      Healthcare
# 5      6            CVS Health                      Healthcare
# 6      7    Berkshire Hathaway                    Conglomerate
# 7      8              Alphabet  Technology and cloud computing
# 8      9  McKesson Corporation                          Health
# 9     10   Chevron Corporation              Petroleum industry
# 10    11               Cencora              Pharmacy wholesale
# 11    12                Costco                          Retail
# 12    13             Microsoft  Technology and cloud computing
# 13    14       Cardinal Health                      Healthcare
# ...

# %%
# Give all the information who works only in Retail industry.
df[df['Industry'] == 'Retail']
# Out:
#     Rank                Name Industry Revenue (USD millions) Revenue growth  \
# 0      1             Walmart   Retail                611,289           6.7%
# 11    12              Costco   Retail                226,954          15.8%
# 19    20      The Home Depot   Retail                157,403           4.1%
# 23    24              Kroger   Retail                148,258           7.5%
# 32    33  Target Corporation   Retail                109,120           2.9%
# 38    39              Lowe's   Retail                 97,059           0.8%
# 52    53          Albertsons   Retail                 77,650           8.0%
# 79    80              Publix   Retail                 54,942          13.5%
# 88    89                 TJX   Retail                 49,936           2.9%
# 95    96            Best Buy   Retail                 46,298          10.6%
#
#     Employees                 Headquarters
# 0   2,100,000        Bentonville, Arkansas
# 11    304,000         Issaquah, Washington
# ...

# %%
HQ_in_Ohio = df[df['Headquarters'].str.contains('Ohio')]
HQ_in_Ohio
# Out:
#     Rank                                 Name  \
# 13    14                      Cardinal Health
# 15    16                   Marathon Petroleum
# 23    24                               Kroger
# 50    51                     Procter & Gamble
# 84    85  Nationwide Mutual Insurance Company
# 89    90              Progressive Corporation
#
#                            Industry Revenue (USD millions) Revenue growth  \
# 13                       Healthcare                181,364          11.6%
# 15               Petroleum industry                180,012          27.6%
# 23                           Retail                148,258           7.5%
# 50  Consumer products manufacturing                 80,187           5.3%
# 84                        Financial                 51,450           8.6%
# 89                        Insurance                 49,611           4.0%
#
#    Employees            Headquarters
# 13    46,035            Dublin, Ohio
# 15    17,800           Findlay, Ohio
# ...

# %%
Reset_revenue = df['Revenue (USD millions)'].str.replace(',','')
Reset_revenue
# Out:
# 0     611289
# 1     513983
# 2     413680
# 3     394328
# 4     324162
# 5     322467
# 6     302089
# 7     282836
# 8     276711
# 9     246252
# 10    238587
# 11    226954
# 12    198270
# 13    181364
# 14    180516
# 15    180012
# 16    175702
# 17    171189
# 18    158057
# 19    157403
# 20    156735
# 21    156595
# 22    154792
# 23    148258
# 24    144547
# 25    136835
# 26    132703
# 27    121596
# 28    121427
# 29    120741
# 30    116609
# 31    115053
# 32    109120
# 33    102301
# 34    101556
# 35    101078
# 36    100338
# 37    100330
# 38     97059
# 39     94943
# 40     93512
# 41     92870
# 42     89876
# 43     89328
# 44     86717
# 45     86859
# 46     82859
# 47     82722
# 48     82156
# 49     81462
# 50     80187
# 51     78620
# 52     77650
# 53     76555
# 54     69898
# 55     68711
# 56     68636
# 57     67232
# 58     67074
# 59     66608
# 60     66036
# 61     65984
# 62     65936
# 63     63054
# 64     62983
# 65     62344
# ...

# %%
# select particular columns

Filter_columns = df.filter(items = ['Name', 'Revenue growth'])
Filter_columns
# Out:
#                                    Name Revenue growth
# 0                               Walmart           6.7%
# 1                                Amazon           9.4%
# 2                            ExxonMobil          44.8%
# 3                                 Apple           7.8%
# 4                    UnitedHealth Group          12.7%
# 5                            CVS Health          10.4%
# 6                    Berkshire Hathaway           9.4%
# 7                              Alphabet           9.8%
# 8                  McKesson Corporation           4.8%
# 9                   Chevron Corporation          51.6%
# 10                              Cencora          11.5%
# 11                               Costco          15.8%
# 12                            Microsoft          18.0%
# 13                      Cardinal Health          11.6%
# 14                                Cigna           3.7%
# 15                   Marathon Petroleum          27.6%
# ...

# %%
Reset_index = df.set_index(['Industry','Rank'])
Reset_index.sort_index()
# Out:
#                                                                         Name  \
# Industry                           Rank
# Aerospace and defense              60                                 Boeing
#                                    62                        Lockheed Martin
# Agriculture cooperative            92                                    CHS
# Agriculture manufacturing          83                             John Deere
# Airline                            87                        Delta Air Lines
#                                    91                      American Airlines
#                                    98                        United Airlines
# Apparel                            95                                   Nike
# Automotive and energy              50                                  Tesla
# Automotive industry                19                     Ford Motor Company
#                                    21                         General Motors
# ...

# %% [markdown]
# # Indexing

# %%
df2 = pd.read_csv(r"F:\Maya_Tech\Data_Analyst\Python\world_population.csv", index_col = "Country")
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# Reset the index
#df2.reset_index(inplace = True)
#df2

# %%
df2.loc['Albania']
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df2.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df2.reset_index(inplace = True)

# %%
df2.set_index(['Continent', 'Country'], inplace = True)
df2.sort_index()
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df2.loc['Africa']
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country
# Algeria                     34  DZA       Algiers       44903225.0
# Angola                      42  AGO        Luanda       35588987.0
# Benin                       77  BEN    Porto-Novo       13352864.0
# Botswana                   144  BWA      Gaborone        2630296.0
# Burkina Faso                58  BFA   Ouagadougou       22673762.0
# Burundi                     78  BDI     Bujumbura       12889576.0
# Cameroon                    53  CMR       Yaounde       27914536.0
# Cape Verde                 171  CPV         Praia         593149.0
# Central African Republic   117  CAF        Bangui        5579144.0
# Chad                        69  TCD     N'Djamena       17723315.0
# Comoros                    163  COM        Moroni         836774.0
# Djibouti                   160  DJI      Djibouti        1120849.0
# DR Congo                    15  COD      Kinshasa       99010212.0
# ...

# %%
df2.loc['Africa','Algeria']
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: (Africa, Algeria), dtype: object

# %%
df2.iloc[2]
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: (Africa, Algeria), dtype: object

# %% [markdown]
# # Group by and Aggregating in Pandas

# %%
Ice_creams = pd.read_csv(r"F:\Maya_Tech\Data_Analyst\Python\Flavors.csv")
Ice_creams
#print(Ice_creams.dtypes)
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = Ice_creams.groupby('Base Flavor').mean(numeric_only = True)
group_by_frame
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
Ice_creams.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
Ice_creams.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
Ice_creams.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
Ice_creams.groupby('Base Flavor').agg({'Flavor Rating': ['mean','max','count','sum']})
# Out:
#             Flavor Rating
#                      mean   max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2
# Vanilla               5.7  10.0     6  34.2

# %%
Ice_creams.groupby(['Base Flavor', 'Liked']).mean(numeric_only = True)
# Out:
#                    Flavor Rating  Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              8.4        7.233333     15.700000
# Vanilla     No               3.6        4.466667      8.066667
#             Yes              7.8        6.833333     14.633333

# %%
Ice_creams.groupby('Base Flavor').describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]
